# %% [markdown]
# # Analysis

# %%
import pandas as pd
from matching_analysis import load_matching, prepare_data, compute_att_pairs, run_did

# %%
df = pd.read_parquet("output/data/monthly_agg.parquet")
df = df[df["price"] == "all"]
